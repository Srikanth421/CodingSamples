# %% [markdown]
# <a href="https://colab.research.google.com/github/Srikanth421/CodingSamples/blob/master/Notebook_1_NLP_Environment_Setup_%26_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Notebook 0. NLP Environment Setup**
#
# > The notebook contains all the code taught in the video NLP Environment Setup
#
# > Find **Exercise #1** at the end of this notebook

# %%
# !pip list #all the packages installed in the pip base environment
# Out:
# Package                  Version
# ------------------------ ---------------
# absl-py                  0.9.0
# alabaster                0.7.12
# albumentations           0.1.12
# altair                   4.0.1
# asgiref                  3.2.3
# astor                    0.8.1
# astropy                  4.0
# atari-py                 0.2.6
# atomicwrites             1.3.0
# attrs                    19.3.0
# audioread                2.1.8
# autograd                 1.3
# Babel                    2.8.0
# backcall                 0.1.0
# backports.tempfile       1.0
# backports.weakref        1.0.post1
# beautifulsoup4           4.6.3
# bleach                   3.1.0
# blis                     0.2.4
# bokeh                    1.4.0
# boto                     2.49.0
# boto3                    1.11.15
# botocore                 1.14.15
# Bottleneck               1.3.1
# branca                   0.3.1
# bs4                      0.0.1
# bz2file                  0.98
# ...

# %%
# !pip search nltk # search in pip is noisy but you can visually find the package you're looking for. The trade of
# Out:
# rake-nltk (1.0.4)                - Python implementation of the Rapid Automatic Keyword Extraction algorithm using NLTK
# nltk (3.4.5)                     - Natural Language Toolkit
#   INSTALLED: 3.2.5
#   LATEST:    3.4.5
# ko-nltk (0.1)                    -
# nltkdata (0.0.1)                 - NLTK Data
# nltkrest (0.12)                  - NLTK as a REST service
# soyuz (0.0.1)                    - NLTK API with SpaCy models.
# nltk_tgrep (1.0.6)               - tgrep2 Searching for NLTK Trees
# nltkjsonnlp (0.0.5)              - The Python NLTK JSON-NLP package
# lektor-natural-language (0.3.1)  - Adds NLTK based template filters.
# cnpt-leos (0.1.1)                - Custom NLTK part of speech tagger
# bluestocking (0.1.2)             - An information extraction toolkit built on top of NLTK.
# wordgrapher (0.3.1)              - Word Graph utility built with NLTK and TextBlob
# FastBLEU (0.0.4)                 - A fast multithreaded C++ implementation of nltk BLEU.
# ...

# %%
# !pip search torch
# Out:
# torch-lighter (0.2.19)                       - Lightweight extension for torch to speed-up prototyping.
# torch-vision (0.1.6.dev0)                    - image and video datasets and models for torch deep learning
# torch (1.4.0)                                - Tensors and Dynamic neural networks in Python with strong GPU acceleration
#   INSTALLED: 1.4.0 (latest)
# deepctr-torch (0.2.0)                        - Easy-to-use,Modular and Extendible package of deep learning based CTR(Click Through Rate) prediction models with PyTorch
# torch-enhance (0.1.1)                        - Image Super-Resolution Library for PyTorch
# torch-specinv (0.1)                          - A pytorch package for Spectrogram Inversion
# fcd-torch (1.0.7)                            - Fr&#233;chet ChemNet Distance on PyTorch
# torch-layers (0.1.2)                         -
# torch-inspect (0.0.3)                        - Utility functions that prints a summary of a model.
# ...

# %%
# !pip search scikit-learn
# Out:
# instaffo-scikit-learn (0.2.2)               - This project contains custom scikit-learn estimators that we use.
# scikit-learn (0.22.2.post1)                 - A set of python modules for machine learning and data mining
#   INSTALLED: 0.22.1
#   LATEST:    0.22.2.post1
# intel-scikit-learn (0.19.2)                 - scikit-learn optimized with Intel(R) Data Analytics Acceleration Library
# scikit-learn-helper (0.0.10)                - Helper code to make easier working with sklearn. https://github.com/aras7/scikit-learn-helper
# sagemaker-scikit-learn-extension (1.1.0)    - Open source library extension of scikit-learn for Amazon SageMaker.
# sparkit-learn (0.2.6)                       - Scikit-learn on PySpark
# spoke-scikit-learn (0.19.dev0)              - A set of python modules for machine learning and data mining
# scikit-ext (0.1.16)                         - Various scikit-learn extensions
# scikit-datasets (0.1.38)                    - Scikit-learn-compatible datasets
# ...

# %%
# !pip install conda
# Out:
# ...
#      |████████████████████████████████| 307kB 4.8MB/s
# ...
#      |████████████████████████████████| 71kB 10.5MB/s
# ...
#      |████████████████████████████████| 112kB 50.3MB/s
# ...
#      |████████████████████████████████| 552kB 53.2MB/s
# ...
#   Created wheel for conda: filename=conda-4.3.16-cp36-none-any.whl size=336938 sha256=f6c2577ef46b1c31eb692f4958871162bad2766f3905e3998121baee8674997d
#   Stored in directory: /root/.cache/pip/wheels/a3/50/79/302742d53e2231ec545cb3791abfdd24de234021ed8e0588a0
# ...
#   Created wheel for pycosat: filename=pycosat-0.6.3-cp36-cp36m-linux_x86_64.whl size=142888 sha256=cb9b68e585edaca3bf73c19f37216857494b57384ccb7783e34ed93551627ed2
#   Stored in directory: /root/.cache/pip/wheels/c4/67/ff/5570304e45814eccef48a3c69c3af25d0456ed3a34eddbbe38
# Successfully built conda pycosat
# ...

# %%
# !Python # to see the python version
# Out:
# /bin/bash: Python: command not found

# %%
# Wish to use the good olf Anaconda? You can run the two cells below to change your Python Distribution and package management to Anaconda

# %%
#installing full Anaconda
# !wget https://repo.anaconda.com/archive/Anaconda3-5.2.0-Linux-x86_64.sh && bash Anaconda3-5.2.0-Linux-x86_64.sh -bfp /usr/local
# Out:
# --2020-03-09 13:27:50--  https://repo.anaconda.com/archive/Anaconda3-5.2.0-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.131.3, 104.16.130.3, 2606:4700::6810:8303, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.131.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 651745206 (622M) [application/x-sh]
# Saving to: ‘Anaconda3-5.2.0-Linux-x86_64.sh’
#
# Anaconda3-5.2.0-Lin 100%[===================>] 621.55M   108MB/s    in 5.7s
#
# 2020-03-09 13:27:56 (108 MB/s) - ‘Anaconda3-5.2.0-Linux-x86_64.sh’ saved [651745206/651745206]
#
# PREFIX=/usr/local
# installing: python-3.6.5-hc3d631a_2 ...
# Python 3.6.5 :: Anaconda, Inc.
# installing: blas-1.0-mkl ...
# installing: ca-certificates-2018.03.07-0 ...
# installing: conda-env-2.6.0-h36134e3_1 ...
# installing: intel-openmp-2018.0.0-8 ...
# installing: libgcc-ng-7.2.0-hdf63c60_3 ...
# installing: libgfortran-ng-7.2.0-hdf63c60_3 ...
# ...

# %%
# To make Python find the modules run:
import sys
sys.path.append('/usr/local/lib/python3.6/site-packages')

# %%
# Verify if Anaconda works
# !conda list nltk
# Out:
# # packages in environment at /usr/local:
# #
# # Name                    Version                   Build  Channel
# nltk                      3.3.0                    py36_0

# %%
# !conda list scikit-learn
# Out:
# # packages in environment at /usr/local:
# #
# # Name                    Version                   Build  Channel
# scikit-learn              0.19.1           py36h7aa7ec6_0

# %%
#checking if CUDA's present and its version number
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2019 NVIDIA Corporation
# Built on Sun_Jul_28_19:07:16_PDT_2019
# Cuda compilation tools, release 10.1, V10.1.243

# %%
#installing the right PyTorch version given the CUDA version
# !conda install pytorch torchvision cudatoolkit=10.1 -c pytorch
# Out:
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.4
#   latest version: 4.8.2
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - cudatoolkit=10.1
#     - pytorch
#     - torchvision
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     olefile-0.46               |             py_0          33 KB
#     six-1.14.0                 |           py36_0          27 KB
#     pip-20.0.2                 |           py36_1         1.9 MB
#     libpng-1.6.37              |       hbc83047_0         364 KB
#     libgcc-ng-9.1.0            |       hdf63c60_0         8.1 MB
#     torchvision-0.5.0          |       py36_cu101         9.1 MB  pytorch
#     readline-7.0               |       h7b6447c_5         392 KB
# ...

# %% [markdown]
# # Exercise 1
# ## a. Check if you have numpy installed using Conda
# ## b. Check if you have numpy installed using PIP
